# %% [markdown]
# # Programming Quantum Computers
# - #### Hands-on Experiential Learning <font color="red">for the Software Engineer</font>

# %% [markdown]
# # Chapter Ch03_03
# # <font color="red">Hands-on</font>:  <font color="blue">Phase Kickback</font>

# %% [markdown]
# ![QC_Programming-red](img/QC_Programming-red.png "QC_Programming-red")
#
# <BR>
#
# <font color="red">**Notice**</font>: All materials herein were <font color="red">**curated**</font> by **Matthew R. Versaggi (profversaggi@gmail.com)** and are released into the open source to foster growth and welfare of expanding the Quantum Computing domain - the only obligation one incurs when using, copying, distributing or referencing this is to kindly reference the author and send me an email so I know how useful the material is to you.
#
# <font color="red">**Notice**</font>: Python Code contributions for the Circle Plots are the work of **David Radcliffe**.
#
# ## Pedagogical Approach: (<font color="red">**Read this first !**</font>)
#
# This material is intended to educate **software engineers** in certain aspects of Quantum Computing, therefore its focus will be on conveying the conceptual ideas in a form digestible to them, and supporting it with exercises to reinforce those concepts.
#
# Because of that pedagogical approach, **this material won't lead with or heavily leverage the concepts and language indigenous to physics and math**, but only in those terms most easily digestible to the modern software engineer.
#
# This Jupyter Notebook is <font color="red">**not intended as a stand alone educational vehicle**</font>  - it's meant to be accompanied by a decicated power point deck that contains the main concepts to be presented by an instructor - **it is intended as a vehicle for a hands on workshop environment to facilitate learning through a guided experience.**
#
# > **Note:-** Because of the above educational approach:
# 1. There is a certain amount of basic Quantum Computing knowledge that is assumed.
# 2. An active internet connection is **always** assumed.
# 3. Online references/links will be provided where appropriate
# 4. References to books will be made where appropriate
# 5. Much of this material is **dense and detailed**, the reader is <font color="red">**cautioned**</font> to be careful and slow to digest the *nuances* of the material.
#
# ## What you will be exposed to - High level:
#
# - Software engineers in the Quantum Computing space need to **<font color="blue">gain a mastery of the simulation frameworks and tools used to understand and solve problems quantumly</font>**. Under the hood, the **<font color="red">simulators mathematically represent the "Ideal" manifestations of quantum hardware</font>** that (theoretically) the "Actual" quantum hardware would behave exactly like. For the software engineer, this is the preferred situation as it permits them to understand and solve problems w/out being bound to the limitations of the hardware as it matures.
#
#
# - Given the above, there are a host of technical concepts that need to be **<font color="red">understood experientially</font>** - we'll intentionally employ a vendor / framework agnostic approach to focus on the delivery of concept understanding and intuition procurement as the main value-add.
#
#
# ## Accompanying Text:
#
# <BR>
#
# <a href="https://www.amazon.com/Programming-Quantum-Computers-Essential-Algorithms/dp/1492039683" target="_blank"><img src="img/OreillyBookImage-small.png" height="250" align=left style="padding:15px;"></a>
#
#
# > The core materials leveraged in this Jupyter Notebook comes from the following book, and is required reading to engage in the problem sets covered.
#
# > The problem sets contained here will be expanded versions of the exercises contained in the book for sake of gaining intuition about the particular concept in question through leveraging various 'other' frameworks, tools, and instruments indigenous to the quantum programming space.
#
#
# > The core idea is that the various "simulators" circuitry (underlying mathematical representations) is considered the "Ideal" at the time of this JNB's construction, and therefore are the bect tools we have to address the problems we are interested in. To avoid being constrained by any particular framework, tool set, and software instruments, the idea is to leverage a host of appropriate "tools" when addressing any particular concept, problem or issue to remaind technology agnostic, but concept and intuition rich.
#
#
# - **Note:** The problems explored are organized and ordered according to chapter.
#
# <BR>
#
# **<font color="red" size=4>Notice</font>:** - Prior to embarking on this notebook the reader is **highly encouraged to procure a <font color="red" size=4>reasonable</font> <font color="blue" size=4>introduction</font>** to the following key programming (and circuit) frameworks used:
#
# 0. <a href="https://oreilly-qc.github.io/" target="_blank"><font color="blue" size=4>QCEngine</font></a>
# 0. <a href="https://qiskit.org/textbook/preface.html" target="_blank"><font color="blue" size=4>Qiskit Tutorial</font></a>, <a href="https://qiskit.org/" target="_blank"><font color="blue" size=4>Qiskit Home</font></a>
# 0. <a href="https://algassert.com/quirk" target="_blank"><font color="blue">QUIRK</font></a>
#
# # <font color="red">Example Problem(s):</font>
#
# **This example problem is archetypal** of how the exercises highlighted in the book can be expanded to include a host of other tools that help build understanding and intuition of the concepts being explored.
#
# - The <font color="blue">QCEngine</font> is a staple, but the <font color="blue">Bloch Sphere Playground Application</font>, the <font color="blue">Quantum Gate Playground</font>, <font color="blue">QUIRK</font>, and <font color="blue">Qiskit</font> are also instructive to leverage when persuing intuition about the concept and will be often used.

# %% [markdown]
# # Phase Kickback

# %% [markdown]
# ![Phase Kickback](img/phase_kickback.png "Phase Kickback")

# %% [markdown]
# # <font color="red">Refresher</font>: -  <font color="blue">Phase Kickback</font>
#
# > - **Definition**: When the **phases** of one register are **conditioned** upon the **values** of another register, then any phase changes executed on the one register **also affects the other registers phases** and are **cumulative** - aka, they get **"kicked back"** to the other register and **"add up"**.
#
#
# ![phase-kickback-diagram](img/phase-kickback-diagram.png "")
#
# <BR>
#
# <img style="float: center;" src="img/binary-table-0-7_excel.png">

# %% [markdown]
# ### <font color="red"> Phase Kickback Trick</font> :  (<font color="blue">QCEngine</font>)
#
# - Experiment with the Program Circuit Output Display (clicking on the various points on the circuit) to see how the circle diagrams behave (for intuitions sake).
# - The **Phase Degrees** should be aprox: (**0, +45, +90, +135**) for decimal numbers (**4, 5, 6 7**).
#
#
# <BR>
#
# ![phase-kickback-trick-circle-charts](img/phase-kickback-trick-circle-charts.png "phase-kickback-trick-circle-charts")
#
# The **Relative Phase** (aka. Rotation)
# - <font color="red">**Important**</font>: Phase operations <font color="red">**only**</font> rotate the circle associated with the **|1>** state and will have <font color="red">**no**</font> effect on the **|0>** state.
# ![circle-plot-phase-rotations](img/circle-plot-phase-rotation.png "")

# %% [markdown]
# ### Post <font color="red">Superposition</font> of Reg #1:
# ![cPhaseKickBack-0dg](img/PhaseKickBack-0dg.png "")

# %% [markdown]
# ### Post <font color="red">45dg</font> Phase Rotation of Reg #2:
# ![cPhaseKickBack-90dg](img/PhaseKickBack-90dg.png "")

# %% [markdown]
# ### Post <font color="red">90dg</font> Phase Rotation of Reg #2:
# ![cPhaseKickBack-135dg](img/PhaseKickBack-135dg.png "")

# %% [markdown]
# ### Enhanced Stock Phase Kickback Example
# - Note the progression from 0=>45=>90=>135 Degrees

# %% [raw]
# // Enhanced Stock Phase Kickback Example
#
# qc.reset(3);
# // Create two registers
# var reg1 = qint.new(2, 'Register 1');
# var reg2 = qint.new(1, 'Register 2');
# reg1.write(0);
# reg2.write(1);
#
# qc.label("Phase Kickback")
# qc.nop();
# // Place the first register in superposition
# reg1.had();
# qc.nop();
#
# // Perform phase rotations on second register,
# //conditioned on qubits from the first
#
# // 45dg Phase Rotation : 4x1
# qc.phase(45, 0x4, 0x1);
# qc.nop();
#
# // 90dg Phase Rotation: 4x2
# qc.phase(90, 0x4, 0x2);
# qc.nop();
#
# qc.label();

# %% [markdown]
# # <font color="blue">QCEngine</font>

# %%
from IPython.display import IFrame
IFrame(src='http://oreilly-qc.github.io?p=3-3', width=900, height=900)
# Out:
#         <iframe
#             width="900"
#             height="900"
#             src="http://oreilly-qc.github.io?p=3-3"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # <font color="blue">Qiskit</font>
#
# ![cPhaseKickBack-135dg](img/PhaseKickBack-135dg.png "")

# %% [markdown]
# ### <font color="blue">Setup</font>

# %%
# Import Qiskit, and set up a Quantum register of 1 Qubit, and set up a Quantum Circuit w/that register
# Note the Helper Functions

import numpy as np
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, execute, Aer, IBMQ, BasicAer
import math
import cmath
import math
import matplotlib.pyplot as P
import matplotlib.pyplot as plt


# Helper Funtion for Normalizing State Vectors
#
def normalize_state_Vector(state_vector):
    for result in state_vector:
        print("Normalized Result: " , round( np.abs(result)**2, 1) )
        
            
## Uncomment the next line to see diagrams when running in a notebook
# %matplotlib inline

# %% [markdown]
# ### <font color="blue">Circuit Construction</font>

# %%
## Example 3-3: Phase Kickback

# Register NE has 2 qubits, Register TWO has only one.
reg1 = QuantumRegister(2, name='reg1')
reg2 = QuantumRegister(1, name='reg2')

qc = QuantumCircuit(reg1, reg2)

# %% [markdown]
# ### <font color="blue">Construct the Phase Kickback Circuit</font>

# %%
# Put Register ONE in Superposition
qc.h(reg1) 

# Execute a QISKIT Controlled-U1 Gate of Pi/4 = 45 Degrees and Pi/2 = 90 Degrees 
# Controlled by Register ONE qubit ZERO and Register ONE qubit ONE targeted on Register TWO, respectively.
# This is a diagonal and symmetric gate that induces a phase on the state 
# of the target qubit, depending on the control state.

qc.cu1(math.pi/4, reg1[0], reg2)
qc.cu1(math.pi/2, reg1[1], reg2)

# %% [markdown]
# ### <font color="blue">Execute batch Job, get results.</font>

# %%
backend = BasicAer.get_backend('statevector_simulator')
job = execute(qc, backend)
result = job.result()

# %% [markdown]
# ### <font color="blue">Print Qstate, draw the circuit.</font>

# %%
outputstate = result.get_statevector(qc, decimals=3)
print(outputstate)

# draw the circuit
qc.draw(output='mpl')        # draw the circuit
# Out:
# [0.5+0.j 0.5-0.j 0.5+0.j 0.5-0.j 0. +0.j 0. +0.j 0. +0.j 0. +0.j]

# %% [markdown]
# ### <font color="blue">Print out the StateVector.</font>

# %%
# Print out normalized statevector  (to gain probabilities)
#
normalize_state_Vector(outputstate)
# Out:
# Normalized Result:  0.2
# Normalized Result:  0.2
# Normalized Result:  0.2
# Normalized Result:  0.2
# Normalized Result:  0.0
# Normalized Result:  0.0
# Normalized Result:  0.0
# Normalized Result:  0.0

# %% [markdown]
# ### <font color="blue">Print out the Circle Plots.</font>
# > - **<font color="red"> IMPORTANT:</font>** - Why are the **QISKIT** circle plots completely different from the **QCEngine** Circle Plots?

# %%
# Print out Circle Notation for intuitions sake

from circle_plot import *
plot_circles(outputstate)

# %% [markdown]
# ### <font color="blue">Print out the Bloch Spheres.</font>
# > - **<font color="red"> IMPORTANT:</font>** - Can the **QISKIT** Bloch Spheres inform us where the Circle Plots Could not?

# %%
# Plot the state vector on a Bloch sphere

from qiskit.tools.visualization import plot_bloch_multivector
plot_bloch_multivector(outputstate)
# Out:
# /Users/nbasup1/miniconda3/envs/my-env/lib/python3.9/site-packages/qiskit/visualization/bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %% [markdown]
# # <font color="red">Graded Exercises</font>  for use <font color="blue">with structured courses.</font>

# %% [markdown]
# ## Experiment with the QISKIT Phase-Kickback Circuit
#
# #### Goto the following link and read it carefully, open the various circuits in IBM Circuit Composer and run them to develop intuition about how QISKIT does things.
#
# <BR>
#
# > - https://qiskit.org/textbook/ch-gates/phase-kickback.html
#
# <BR>
#
# ## <font color="red">Your Task:</font>
#
# In the link above, **you are given the below three exercises** to help explore phase kickback using QISKIT.
#
# ![cPhaseKickBack-Qiskit-Questions](img/PhaseKickback_QISKIT_Question.png "")
#
#
# <BR>
#
# 0. Implement the curcuits for these three questions below - make sure you print the Bloch Spheres for each question, and use the QISKIT code template above for inspiration.
# 0. Then answer the three questions below that.

# %% [markdown]
# ##  <font color="blue">Your QISKIT Code goes below:</font>

# %% [markdown]
# ###  <font color="blue">Exercise #1 Code goes below:</font>

# %%
# Import Qiskit, and set up a Quantum register of 1 Qubit, and set up a Quantum Circuit w/that register
# Note the Helper Functions

import numpy as np
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, execute, Aer, IBMQ, BasicAer
import math
import cmath
import math
import matplotlib.pyplot as P
import matplotlib.pyplot as plt


# Helper Funtion for Normalizing State Vectors
#
def normalize_state_Vector(state_vector):
    for result in state_vector:
        print("Normalized Result: " , round( np.abs(result)**2, 1) )
        
            
## Uncomment the next line to see diagrams when running in a notebook
# %matplotlib inline

# %%
## Example 3-3: Phase Kickback

# Register NE has 2 qubits
reg1 = QuantumRegister(2, name='reg1')

qc = QuantumCircuit(reg1)

# %%
# Put Register ONE in Superposition
qc.h(reg1[0]) 

# Execute a QISKIT Controlled-U1 Gate of Pi/4 = 45 Degrees 
qc.cu1(math.pi/4, reg1[0], reg1[1])

# %%
backend = BasicAer.get_backend('statevector_simulator')
job = execute(qc, backend)
result = job.result()

# %%
outputstate = result.get_statevector(qc, decimals=3)
print(outputstate)

# draw the circuit
qc.draw(output='mpl')        # draw the circuit
# Out:
# [0.707+0.j 0.707-0.j 0.   +0.j 0.   +0.j]

# %%
# Print out normalized statevector  (to gain probabilities)
#
normalize_state_Vector(outputstate)
# Out:
# Normalized Result:  0.5
# Normalized Result:  0.5
# Normalized Result:  0.0
# Normalized Result:  0.0

# %%
# Print out Circle Notation for intuitions sake

from circle_plot import *
plot_circles(outputstate)

# %%
# Plot the state vector on a Bloch sphere

from qiskit.tools.visualization import plot_bloch_multivector
plot_bloch_multivector(outputstate)
# Out:
# /Users/nbasup1/miniconda3/envs/my-env/lib/python3.9/site-packages/qiskit/visualization/bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %% [markdown]
# ###  <font color="blue">Exercise #2 Code goes below:</font>

# %%
# Import Qiskit, and set up a Quantum register of 1 Qubit, and set up a Quantum Circuit w/that register
# Note the Helper Functions

import numpy as np
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, execute, Aer, IBMQ, BasicAer
import math
import cmath
import math
import matplotlib.pyplot as P
import matplotlib.pyplot as plt


# Helper Funtion for Normalizing State Vectors
#
def normalize_state_Vector(state_vector):
    for result in state_vector:
        print("Normalized Result: " , round( np.abs(result)**2, 1) )
        
            
## Uncomment the next line to see diagrams when running in a notebook
# %matplotlib inline

# %%
## Example 3-3: Phase Kickback

# Register NE has 2 qubits
reg1 = QuantumRegister(2, name='reg1')

qc = QuantumCircuit(reg1)

# %%
# Put Qubit(0) in Superposition
# Put Qubit(1) in |1> position
qc.h(reg1[0]) 
qc.x(reg1[1])

# Execute a QISKIT Controlled SDG-Gate of -Pi/2 = 90 Degrees
qc.cu1(-math.pi/2, reg1[1], reg1[0])

# %%
backend = BasicAer.get_backend('statevector_simulator')
job = execute(qc, backend)
result = job.result()

# %%
outputstate = result.get_statevector(qc, decimals=3)
print(outputstate)

# draw the circuit
qc.draw(output='mpl')        # draw the circuit
# Out:
# [0.   +0.j    0.   +0.j    0.707-0.j    0.   -0.707j]

# %%
# Print out normalized statevector  (to gain probabilities)
#
normalize_state_Vector(outputstate)
# Out:
# Normalized Result:  0.0
# Normalized Result:  0.0
# Normalized Result:  0.5
# Normalized Result:  0.5

# %%
# Print out Circle Notation for intuitions sake

from circle_plot import *
plot_circles(outputstate)

# %%
# Plot the state vector on a Bloch sphere

from qiskit.tools.visualization import plot_bloch_multivector
plot_bloch_multivector(outputstate)
# Out:
# /Users/nbasup1/miniconda3/envs/my-env/lib/python3.9/site-packages/qiskit/visualization/bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %% [markdown]
# ###  <font color="blue">Exercise #3 Code goes below:</font>

# %%
# Import Qiskit, and set up a Quantum register of 1 Qubit, and set up a Quantum Circuit w/that register
# Note the Helper Functions

import numpy as np
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, execute, Aer, IBMQ, BasicAer
import math
import cmath
import math
import matplotlib.pyplot as P
import matplotlib.pyplot as plt


# Helper Funtion for Normalizing State Vectors
#
def normalize_state_Vector(state_vector):
    for result in state_vector:
        print("Normalized Result: " , round( np.abs(result)**2, 1) )
        
            
## Uncomment the next line to see diagrams when running in a notebook
# %matplotlib inline

# %%
## Example 3-3: Phase Kickback

# Register NE has 2 qubits
reg1 = QuantumRegister(2, name='reg1')

qc = QuantumCircuit(reg1)

# %%
# Put both the quibts in |1> position
qc.x(reg1) 
#qc.x(reg1[1])

# Execute a QISKIT Controlled-U1 Gate of Pi/4 = 45 Degrees 

qc.cu1(math.pi/4, reg1[0], reg1[1])

# %%
backend = BasicAer.get_backend('statevector_simulator')
job = execute(qc, backend)
result = job.result()

# %%
outputstate = result.get_statevector(qc, decimals=3)
print(outputstate)

# draw the circuit
qc.draw(output='mpl')        # draw the circuit
# Out:
# [0.   +0.j    0.   +0.j    0.   +0.j    0.707+0.707j]

# %%
# Print out normalized statevector  (to gain probabilities)
#
normalize_state_Vector(outputstate)
# Out:
# Normalized Result:  0.0
# Normalized Result:  0.0
# Normalized Result:  0.0
# Normalized Result:  1.0

# %%
# Print out Circle Notation for intuitions sake

from circle_plot import *
plot_circles(outputstate)

# %%
# Plot the state vector on a Bloch sphere

from qiskit.tools.visualization import plot_bloch_multivector
plot_bloch_multivector(outputstate)
# Out:
# /Users/nbasup1/miniconda3/envs/my-env/lib/python3.9/site-packages/qiskit/visualization/bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %% [markdown]
# ###  <font color="blue">Your written answers go below:</font>

# %% [raw]
# What would be the resulting state of the control qubit (q0) if the target qubit (q1) was in the state |0⟩ ? (as shown in the circuit below)? Use Qiskit to check your answer. - In superposition state with no phase rotation happening as the phase rotation doesnt happen if the state is |0>
# What would happen to the control qubit (q0) if the target qubit (q1) was in the state |1⟩, and the circuit used a controlled-Sdg gate instead of the controlled-T (as shown in the circuit below)? - Qubit(0) will remain in |0 state with phase rotation of -90 Degrees.
# What would happen to the control qubit (q0) if it was in the state |1⟩ instead of the state |+⟩ before application of the controlled-T (as shown in the circuit below)? - It carries the state of |1> along with the Qubit(1) to provide a value and a phase rotation of 45 Degrees happening after the Controlled T-gate .

# %% [markdown]
# ![the-end](img/the-end.png "the-end")
